# %% [markdown]
# # **Unidad 1: Fundamentos de Python para PLN**

# %% [markdown]
# Cuando entregues tu cuaderno, debes nombrar el fichero (.ipynb) de la siguiente manera:
#
# (3 últimos dígitos del alumno 1)_(3 últimos dígitos del alumno 2)_(UD+número)
#
# Por ejemplo:
# - Dos alumnos entregan las actividades evaluables de la Unidad 1
# - Identificador alumno 1: 200800331
# - Identificador alumno 2: 200800229
#
# Nombre del fichero: `331_229_UD1.ipynb`

# %% [markdown]
# ## 🧾 Actividades propuestas

# %% [markdown]
# 📌 **Instrucciones para el alumno**
#
# *   Realiza las dos siguientes actividades prácticas de código (añade tantas celdas de código consideres para el ejercicio; no tiene por qué estar todo recogido en una única celda) y responde en una celda de markdown a la pregunta final de cada una de las dos actividades.
#
# *   Responde a las preguntas de reflexión obligatorias en celdas de markdown.

# %% [markdown]
# ### ✍️ Actividad 1 – Personalización
# - Sustituye el texto que hemos trabajado en el cuaderno principal de la unidad por otro fragmento institucional o informativo real, y guárdalo en la variable 'texto_act1'.
# - Ejecuta el código completo trabajado en el cuaderno principal de la unidad sobre tu texto elegido (añade para ello el código en celdas de código a continuación de estas instrucciones).
# - Redacta un análisis comparativo de los resultados que has obtenido tras aplicar el código sobre tu texto elegido con los del texto sobre el que trabajamos en el cuaderno principal de la unidad (añade para ello el texto en una celda de markdown a continuación de estas instrucciones).

# %% [markdown]
# ### ✍️ Actividad 2 – Comparación con traducción automática
# - Traduce con un TA el texto que elegiste para la Actividad 1 (por ejemplo, utiliza DeepL), y guárdalo en la variable `texto_act2`.
# - Analiza su legibilidad usando el mismo método que aprendimos en el cuaderno principal de la unidad (añade el código en celdas de código a continuación de estas instrucciones).
# - ¿Es más o menos accesible que el texto original? Responde de forma argumentada y bien razonada en una celda de markdown a continuación de estas instrucciones.

# %% [markdown]
# ## 💬 Preguntas de reflexión

# %% [markdown]
# Responde a cada una de la siguientes preguntas en una celda de markdown a continuación.
#
# 1. ¿Qué tipo de textos presentan mayor complejidad?
# 2. ¿Podrías adaptar este script a textos jurídicos o técnicos?
# 3. ¿Qué limitaciones ves en este análisis?
# 4. ¿Cómo mejorarías este sistema para su uso profesional?
# 5. ¿Qué otras características lingüísticas automatizables podrías incluir?

# %% [markdown]
# **Retos adicionales opcionales:**
#
# *   ¿Puedes mejorar la estimación de sílabas?
# *   ¿Qué otras métricas (como longitud media de palabra o número de frases) podrías incluir?
# *   ¿Podrías generar una visualización simple del análisis?

# %% [markdown]
# ## 🧮 Rúbrica de evaluación

# %% [markdown]
# ⚖️ **Peso de esta actividad en la nota final:** actividad práctica 1 **30 %** · actividad práctica 2 **30 %** · preguntas de reflexión **40 %**
#
# 🧭 **Cómo se evalúa:** se valora **el procedimiento, no solo el resultado**. Resuelve la actividad con el método trabajado en el cuaderno principal de la unidad. Organizar el código a tu manera, usar otros nombres de variables o resolverlo de forma más breve **no penaliza**, siempre que se reconozca ese método. Lo que sí penaliza es sustituirlo por librerías o herramientas que no hemos trabajado y que no explicas.

# %% [markdown]
# | Criterio | Excelente (9-10) | Notable (7-8) | Aprobado (5-6) | Insuficiente (0-4) |
# |---|---|---|---|---|
# | **Comprensión del código** | Explica y adapta con sentido | Ejecuta y modifica levemente | Ejecuta sin comprender bien | No ejecuta el código, o no aplica el procedimiento de la unidad |
# | **Actividades personalizadas** | Textos pertinentes, análisis profundo | Textos válidos, análisis básico | Falta de reflexión o ejemplos pobres | No hay texto propio, o falta el análisis |
# | **Preguntas de reflexión** | Críticas y bien argumentadas | Respuestas simples pero válidas | Incompletas o poco relevantes | Sin responder, o sin relación con la unidad |
# | **Presentación en Markdown** | Clara, estructurada, sin errores | Adecuada con pequeños errores | Confusa o sin formato adecuado | Sin formato, ilegible o ausente |
