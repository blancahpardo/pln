# %% [markdown]
# # 🧪 Unidad 7. Extracción automática de terminología

# %% [markdown]
# Cuando entregues tu cuaderno, debes nombrar el fichero (.ipynb) de la siguiente manera:
#
# (3 últimos dígitos del alumno 1)_(3 últimos dígitos del alumno 2)_(UD+número)
#
# Por ejemplo:
# - Dos alumnos entregan las actividades evaluables de la Unidad 7
# - Identificador alumno 1: 200800331
# - Identificador alumno 2: 200800229
#
# Nombre del fichero: `331_229_UD7.ipynb`

# %% [markdown]
# ## 🧾 Actividades propuestas

# %% [markdown]
# ### 🧩 Actividad 1 — Cambia el umbral de frecuencia
#
# 1. Con los mismos textos y el código original empleado en la parte práctica guiada del cuaderno principal de PLN7, cambia `min_freq=2` a `min_freq=3` para unigramas y bigramas.
# 2. Compara:
#    - ¿qué términos desaparecen?
#    - ¿cuáles se mantienen?
#
# **📤 Entrega:** resuelve el ejercicio añadiendo todo el código e imprime por pantalla los listados con top-10 antes/después.
# Finalmente, añade una celda de markdown con un comentario elaborado por ti sobre la pregunta del punto 2 (150-200 palabras).

# %% [markdown]
# ### 🧩 Actividad 2 — Sustituye los corpus por textos propios
# 1. Crea `corpus_especializado` con los fragmentos que se indican más abajo.
#
# 2. Crea `corpus_general` con los fragmentos que se indican más abajo.
#
# 3. Ejecuta el pipeline y genera el mini-glosario.
#
# 📤 **Entrega:**
# - Top-15 términos candidatos (tabla)
# - mini-glosario impreso (con KWIC)
# - comentario elaborado por ti (150-200 palabras): ¿qué 5 términos te parecen más “válidos” y por qué?

# %% [markdown]
# **Corpus especializado**
#
# *Texto 1*
#
# En lingüística de corpus, un corpus se construye con criterios claros. Un corpus bien diseñado facilita la anotación y el análisis.
# La anotación incluye decisiones sobre categorías y niveles de descripción. En esta práctica, la anotación se centra en el etiquetado morfosintáctico.
# El etiquetado morfosintáctico permite estudiar patrones y usos en un corpus.
# Además, la frecuencia relativa ayuda a comparar unidades entre corpus.
# Para explorar ejemplos, usamos concordancias KWIC en el corpus.
#
# *Texto 2*
#
# Un corpus anotado permite investigar fenómenos lingüísticos con más precisión.
# La anotación puede incluir lemmatización y también etiquetado morfosintáctico.
# La lemmatización reduce variantes como formas flexionadas y facilita el recuento en el corpus.
# En lingüística de corpus, los ngramas ayudan a detectar expresiones recurrentes en el corpus.
# Los ngramas son útiles para observar regularidades y construir listas de candidatos.
#
# *Texto 3*
#
# El análisis de colocaciones se apoya en medidas de asociación y en la frecuencia.
# En este cuaderno, el análisis de colocaciones se aproxima con ngramas y filtros por frecuencia.
# La frecuencia relativa es importante para comparar el corpus especializado con un corpus general.
# También generamos concordancias KWIC para ver el contexto y validar candidatos.
# Las concordancias KWIC muestran una palabra en su entorno dentro del corpus.
#
# *Texto 4*
#
# Para estudiar unidades léxicas en lingüística de corpus, se usan concordancias y listados.
# Las concordancias KWIC permiten observar ejemplos de uso real en el corpus.
# La lemmatización ayuda a agrupar ocurrencias y mejorar el análisis.
# En tareas de extracción, el análisis de colocaciones puede señalar términos multi-palabra.
# En este corpus, el análisis de colocaciones se revisa con ejemplos y repetición.
# Además, lingüística de corpus y corpus aparecen como conceptos centrales.
#
# *Texto 5*
#
# En proyectos de anotación, se define un esquema y se documenta el proceso.
# La anotación debe ser consistente para que el corpus sea reutilizable.
# Para tareas automáticas, el etiquetado morfosintáctico se usa como base.
# En comparación de corpus, la frecuencia relativa destaca unidades características.
# En lingüística de corpus, un corpus especializado favorece candidatos de terminología.
#
# **Corpus general**
#
# *Texto 1*
#
# La economía global atraviesa cambios importantes. Los precios y el empleo influyen en la vida diaria.
# Muchas familias ajustan su presupuesto ante la incertidumbre. Las decisiones políticas afectan al mercado.
#
# *Texto 2*
#
# La educación se enfrenta a retos de organización y recursos. El aprendizaje en el aula depende del contexto.
# Las metodologías cambian con el tiempo. La motivación del alumnado es clave en el proceso educativo.
#
# *Texto 3*
#
# La cultura incluye tradiciones, cine y literatura. Los eventos culturales atraen a personas de distintos lugares.
# El patrimonio histórico se conserva con iniciativas públicas y privadas.
#
# *Texto 4*
#
# El deporte genera interés durante todo el año. Los equipos preparan sus temporadas con intensidad.
# Las competiciones despiertan emoción y los aficionados siguen los resultados con atención.
#
# *Texto 5*
#
# La salud es una prioridad en la sociedad. La prevención y los hábitos saludables mejoran el bienestar.
# Los sistemas sanitarios coordinan recursos para atender a la población.

# %% [markdown]
# ### 🧠 Actividad 3 — Reflexión crítica (sin código)
#
# Responde (80-100 palabras por pregunta):
# 1. ¿Qué gana un enfoque basado en frecuencias frente a uno “neuronal”?
# 2. ¿Qué problemas aparecen si el corpus general es muy pequeño o no representativo?
# 3. ¿Qué tipo de términos crees que este método detecta peor? (pistas: variantes, sinónimos, términos raros)
# 4. ¿Cómo mejorarías el método sin perder interpretabilidad?
#
# 📤 **Entrega:** texto en Markdown.

# %% [markdown]
# ## 📋 Rúbrica de evaluación

# %% [markdown]
# ⚖️ **Peso de esta actividad en la nota final:** Actividad 1 **30 %** · Actividad 2 **30 %** · Actividad 3, reflexión crítica **40 %**
#
# 🧭 **Cómo se evalúa:** se valora **el procedimiento, no solo el resultado**. Resuelve la actividad con el método trabajado en el cuaderno principal de la unidad. Organizar el código a tu manera, usar otros nombres de variables o resolverlo de forma más breve **no penaliza**, siempre que se reconozca ese método. Lo que sí penaliza es sustituirlo por librerías o herramientas que no hemos trabajado y que no explicas.

# %% [markdown]
# | Criterio | Excelente (9-10) | Notable (7-8) | Aprobado (5-6) | Insuficiente (0-4) |
# |---|---|---|---|---|
# | Pipeline completo | Reproducible, claro y justificado | Correcto con detalles | Funciona pero poco claro | No funciona |
# | N-gramas + filtros | Bien aplicados y explicados | Correctos | Parcial | Incorrecto |
# | Comparación (weirdness) | Implementación + interpretación | Implementa bien | Interpreta poco | Incorrecto |
# | Mini-glosario (KWIC) | Ejemplos útiles y relevantes | Correcto | Pocos/ruidosos | No hay |
# | Reflexión | Crítica y bien argumentada | Adecuada | Superficial | No responde |
# | Presentación | Cuaderno limpio y legible | Bien | Algo desordenado | Caótico |
