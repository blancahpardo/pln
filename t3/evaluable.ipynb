# %% [markdown]
# # **Unidad 3: Preprocesamiento y análisis morfosintáctico con spaCy**

# %% [markdown]
# Cuando entregues tu cuaderno, debes nombrar el fichero (.ipynb) de la siguiente manera:
#
# (3 últimos dígitos del alumno 1)_(3 últimos dígitos del alumno 2)_(UD+número)
#
# Por ejemplo:
# - Dos alumnos entregan las actividades evaluables de la Unidad 3
# - Identificador alumno 1: 200800331
# - Identificador alumno 2: 200800229
#
# Nombre del fichero: `331_229_UD3.ipynb`

# %% [markdown]
# ## 🧾 Actividad propuesta

# %% [markdown]
# ### 🧭 Tarea simulada profesional:
#
# Tu cliente farmacéutico te ha enviado un conjunto de fragmentos de prospectos de medicamentos. Debes aplicar el pipeline de limpieza y generar una versión procesada de los textos para integrarlos en el sistema de traducción automática que están desarrollando.
#
# *texto_cliente =
# Este medicamento está indicado para el alivio temporal del dolor leve o moderado, como el asociado a cefaleas, contracturas musculares o molestias articulares.
# Debe administrarse por vía oral con un vaso de agua, preferiblemente después de las comidas, para reducir la irritación gástrica.
# No se recomienda su uso en pacientes con antecedentes de úlcera péptica, insuficiencia hepática o renal grave.
# En caso de sobredosis, pueden aparecer síntomas como náuseas, vómitos, somnolencia o dificultad para respirar, por lo que se debe acudir inmediatamente a un centro médico.
# El tratamiento no debe prolongarse más de 10 días sin la supervisión de un profesional de la salud.
# Si los síntomas persisten o empeoran, consulte a su médico o farmacéutico.
# Este fármaco puede interaccionar con anticoagulantes, diuréticos o medicamentos antihipertensivos, modificando su eficacia o aumentando el riesgo de efectos secundarios.
# No se debe consumir alcohol durante el tratamiento, ya que puede potenciar la toxicidad hepática del principio activo.
# Las mujeres embarazadas o en período de lactancia deben consultar previamente con su médico antes de iniciar el uso del medicamento.
# Conservar el envase en un lugar fresco y seco, protegido de la luz solar directa, y mantener fuera del alcance de los niños.
# Ante cualquier reacción adversa no descrita en este prospecto, se recomienda informar al sistema nacional de farmacovigilancia o a su médico de referencia.*

# %% [markdown]
# El archivo original puede estar plagado de estructuras informales, puntuación variable, palabras técnicas y duplicidades. Tu misión es limpiar y lematizar todo el corpus.
#
# Al final, entrega:
#
# *   Script con cada paso explicado (con #): normalización (conversión a minúsculas), eliminación de signos de puntuación, tokenización, eliminación de stopwods, lematización de tokens filtrados, glosario preliminar con sus frecuencias ordenado alfabéticamente y glosario técnico (sustantivos) con su contexto. Imprímelo todo por pantalla.
#
# *   Resumen (120-150 palabras) donde expliques tus decisiones lingüísticas.
#
#
# **Objetivo:** Aplicar el pipeline de procesamiento de lenguaje natural aprendido para limpiar, tokenizar y lematizar textos técnicos reales.
#
#
# | Criterio                              | ¿Qué se espera de ti?                                                                                                                             |
# | ------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Pipeline bien estructurado**        | Has aplicado los pasos del preprocesamiento en el orden correcto: normalización, limpieza, tokenización, eliminación de stopwords y lematización. |
# | **Uso correcto de spaCy**             | Has cargado el modelo español, procesado el texto con `nlp()` y usado correctamente los objetos `doc`, `token`, etc.                              |
# | **Limpieza y lematización adecuadas** | Has eliminado correctamente la puntuación y las palabras vacías, y presentado una lista clara de lemas relevantes.                                |
# | **Explicación paso a paso clara**     | Cada paso de tu script está comentado, y explicas para qué sirve y qué transforma.                                                                |
# | **Resumen lingüístico argumentado**   | Has escrito un resumen breve (120-150 palabras) explicando tus decisiones lingüísticas (por ejemplo, por qué eliminaste ciertas palabras).             |

# %% [markdown]
# ## 💬 Preguntas de reflexión

# %% [markdown]
# ### Responde a las siguientes preguntas en una celda de markdown:
#
# 1. ¿Qué decisiones tomaste sobre qué palabras eliminar o conservar?
# 2. ¿Crees que en contextos técnicos deberíamos redefinir las “stopwords”?
# 3. ¿Qué pasaría si quitáramos palabras como “no”, “sin”, “antes”? ¿Tiene impacto?
# 4. ¿Detectaste palabras con múltiples significados que podrían afectar al entrenamiento?
# 5. ¿Cuáles crees que son las diferencias entre lematizar y simplemente dividir en palabras?
#
# Objetivo: Demostrar comprensión crítica del impacto del preprocesamiento en el procesamiento del lenguaje natural técnico.
#
# | Criterio                                    | ¿Qué se espera de ti?                                                                                                 |
# | ------------------------------------------- | --------------------------------------------------------------------------------------------------------------------- |
# | **Reflexión sobre stopwords**               | Reconoces que en textos técnicos algunas palabras que suelen eliminarse (como "no" o "sin") pueden ser relevantes.    |
# | **Decisiones lingüísticas conscientes**     | Explicas qué criterios usaste para conservar o eliminar términos y cómo podrían afectar al sistema de traducción.     |
# | **Conciencia de ambigüedades léxicas**      | Detectas palabras que podrían tener varios significados y mencionas posibles riesgos en su interpretación automática. |
# | **Diferencias entre lematizar y tokenizar** | Comparas adecuadamente ambos procesos y entiendes la ventaja de lematizar para tareas como traducción o análisis.     |
# | **Argumentación clara y personal**          | Tus respuestas son personales, justificadas y bien conectadas con lo aprendido en la unidad.                          |

# %% [markdown]
# ## 🧮 Rúbrica de evaluación

# %% [markdown]
# ⚖️ **Peso de esta actividad en la nota final:** desarrollo del código **45 %** · resumen de decisiones **15 %** · preguntas de reflexión **40 %**
#
# 🧭 **Cómo se evalúa:** se valora **el procedimiento, no solo el resultado**. Resuelve la actividad con el método trabajado en el cuaderno principal de la unidad. Organizar el código a tu manera, usar otros nombres de variables o resolverlo de forma más breve **no penaliza**, siempre que se reconozca ese método. Lo que sí penaliza es sustituirlo por librerías o herramientas que no hemos trabajado y que no explicas.

# %% [markdown]
# | Criterio de evaluación                              | Excelente (9-10)                                                                                    | Notable (7-8)                                                                | Aprobado (5-6)                                                                 | Insuficiente (0-4)                                                     |
# | --------------------------------------------------- | ------------------------------------------------------------------------------------------------ | -------------------------------------------------------------------------- | ----------------------------------------------------------------------------- | ---------------------------------------------------------------------- |
# | **Diseño del pipeline de limpieza y lematización**  | Todos los pasos del preprocesamiento están presentes, en orden lógico y bien implementados.      | El pipeline es claro y mayormente completo, con leves ausencias o errores. | El pipeline incluye los pasos esenciales, pero es poco claro o inconsistente. | El pipeline está incompleto, mal organizado o presenta errores graves. |
# | **Uso de spaCy y herramientas NLP**                 | Uso correcto y eficiente de `spaCy` (modelo, tokens, lemas, PoS), bien integrado en el pipeline. | Uso adecuado de spaCy, aunque con aplicaciones algo básicas o repetitivas. | Uso mínimo o parcial de spaCy; hay funciones mal aplicadas.                   | No se usa spaCy correctamente o está ausente.                          |
# | **Explicaciones y documentación del código**        | Cada paso del código está bien comentado y explicado con claridad para el lector.                | Las explicaciones son correctas aunque no siempre detalladas.              | Comentarios escasos o poco informativos.                                      | Código sin comentarios o explicaciones confusas.                       |
# | **Reflexión lingüística y técnica**                 | Argumentación sólida sobre las decisiones de limpieza, stopwords y contexto técnico.             | Reflexión clara pero algo superficial.                                     | Reflexión limitada o genérica.                                                | Reflexión incoherente o ausente.                                       |
# | **Presentación del trabajo y organización general** | Trabajo bien presentado, ordenado, con estructura clara y sin errores formales.                  | Presentación adecuada con leves problemas de formato o claridad.           | Presentación irregular, aunque comprensible.                                  | Presentación desordenada o difícil de seguir.                          |
