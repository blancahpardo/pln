# %% [markdown]
# # **Unidad 5. Evaluación de traducciones automáticas**

# %% [markdown]
# Cuando entregues tu cuaderno, debes nombrar el fichero (.ipynb) de la siguiente manera:
#
# (3 últimos dígitos del alumno 1)_(3 últimos dígitos del alumno 2)_(UD+número)
#
# Por ejemplo:
# - Dos alumnos entregan las actividades evaluables de la Unidad 5
# - Identificador alumno 1: 200800331
# - Identificador alumno 2: 200800229
#
# Nombre del fichero: `331_229_UD5.ipynb`

# %% [markdown]
# ## 🧾 Actividades propuestas

# %% [markdown]
# Realiza las siguientes actividades aplicando lo que has aprendido en el cuaderno. No necesitas programar nada nuevo, solo reutiliza el código ya presentado y, a continuación, interpreta tú los resultados, al igual que lo hicimos con el caso de ejemplo de este cuaderno:

# %% [markdown]
# ### 1. **Evaluación léxica sobre un fragmento narrativo**

# %% [markdown]
# Evalúa la traducción automática (con respecto a una humana de referencia) que se muestra a continuación utilizando las siguientes métricas: precisión léxica, recall, F1-score, Jaccard y Exact Match:
#
# **Traducción humana (guárdala en la variable `TH1`):**
#
# Los viajeros caminaban lentamente por la senda que cruzaba el bosque. El viento movía las hojas secas bajo sus pies, y el sonido era el único que rompía el silencio de la tarde. A lo lejos, podían oír el canto de algún ave que se posaba en la rama de un árbol cercano. La luz del sol filtrada entre las hojas creaba manchas doradas sobre el suelo cubierto de musgo, y cada paso levantaba un pequeño polvo que se mezclaba con el aroma humedecido de la tierra y la madera. Los viajeros conversaban en voz baja, disfrutando del frescor del bosque y la calma que les rodeaba, sin prisa por llegar a su destino. De repente, uno de ellos detuvo la marcha y señaló hacia una pequeña cabaña escondida entre los árboles. Parecía abandonada, pero las ventanas tenían cortinas que ondulaban con la brisa. La curiosidad los llevó a acercarse, mientras la sombra de las nubes avanzaba lentamente sobre el paisaje. Era un lugar que invitaba a la tranquilidad, a la reflexión profunda, lejos del bullicio de las ciudades y el ruido constante del mundo moderno.
#
# **Traducción automática (guárdala en la variable `TA1`):**
#
# Los caminantes avanzaban despacio por el camino que atravesaba el bosque cerrado. El viento levantaba las hojas secas que crujían bajo sus pasos, y el único sonido que rompía el silencio era el murmullo del aire. Desde lejos, escuchaban el canto de un pájaro que estaba en la rama de un árbol próximo. La luz del sol pasaba a través de las hojas y creaba manchas doradas en el suelo cubierto de hierba y musgo. Cada paso levantaba polvo que se mezclaba con el aroma fresco de la tierra y la madera. Los caminantes hablaban en voz baja, disfrutando el fresco del bosque y la tranquilidad que les rodeaba, sin apuro por llegar a su destino. De repente, uno de ellos paró y señaló una cabaña pequeña que estaba oculta entre los árboles. Parecía vieja, pero las ventanas tenían cortinas que se movían con la brisa. La curiosidad les hizo acercarse mientras la sombra de las nubes se desplazaba lentamente sobre el paisaje. Era un sitio pacífico que invitaba a la reflexión, lejos del ruido de la ciudad y del mundo moderno.
#
# -----
#
# Una vez hayas obtenido los resultados cuantitativos, interpreta tú mismo y sin ayuda externa los resultados de cada una de las métricas, y proporciona unas conclusiones globales finales, del mismo modo que hicimos en clase al explicar este cuaderno de PLN5 con los textos de ejemplo. La discusión (interpretación) de los resultados debes desarrollarla y argumentarla debidamente en una celda de markdown a continuación del código de esta actividad.

# %% [markdown]
# ### 2. **BLEU y Exact Match en una descripción científica**

# %% [markdown]
# Utilizando Python, calcula la puntuación BLEU y determina si hay coincidencia exacta con esta pareja:
#
# **Traducción humana (guárdala en la variable `TH2`):**
#
# Las ballenas son mamíferos marinos que respiran aire mediante pulmones. Son conocidas por su gran tamaño y su comportamiento social complejo. Habitan en los océanos de todo el mundo y migran largas distancias para alimentarse y reproducirse. Se alimentan de peces, plancton o pequeños crustáceos que filtran del agua mediante sus barbas. A pesar de su tamaño, son animales muy ágiles y pueden nadar a grandes velocidades para evadir depredadores o buscar alimento. Sus cantos y sonidos juegan un papel fundamental en la comunicación entre individuos, especialmente durante la temporada de apareamiento. Además, las ballenas cumplen una función ecológica importante al contribuir a la regulación de los ecosistemas marinos y al ciclo de nutrientes en el océano.
#
# **Traducción automática (guárdala en la variable `TA2`):**
#
# Las ballenas son animales marinos que necesitan respirar aire con pulmones. Tienen un tamaño enorme y formas sociales complejas. Viven en todos los océanos y hacen migraciones largas para alimentarse y reproducirse. Su dieta incluye peces, plancton y pequeños crustáceos que atrapan del agua usando sus barbas. Aunque son grandes, se mueven rápido y con agilidad, ya sea para escapar de depredadores o para buscar alimento. Usan canciones y sonidos para comunicarse, especialmente en épocas de apareamiento. También son importantes para los ecosistemas marinos porque ayudan a regularlos y facilitan el ciclo de nutrientes en el océano.
#
# ------
#
# Una vez hayas obtenido los resultados cuantitativos, interpreta tú mismo y sin ayuda externa los resultados de cada una de las métricas, y proporciona unas conclusiones globales finales, del mismo modo que hicimos en clase al explicar este cuaderno de PLN5 con los textos de ejemplo. La discusión (interpretación) de los resultados debes desarrollarla y argumentarla debidamente en una celda de markdown a continuación del código de esta actividad.

# %% [markdown]
# ### 3. **Traducción automática desde francés y evaluación completa**

# %% [markdown]
# Usa `GoogleTranslator` para traducir el siguiente fragmento del francés al español (guarda el resultado de esa traducción automática en la variable **`TA3`**), y evalúa la calidad de la traducción usando todas las métricas que hemos visto en este cuaderno.
#
# **Texto original en francés (guárdala en la variable `FR3`):**
#
#
# -----
#
# Una vez hayas obtenido los resultados cuantitativos, interpreta tú mismo y sin ayuda externa los resultados a las métricas automáticas (cómo afectan estos cambios de sinonimia a las métricas, pestando especial atención a Exact Match y a BLEU), y proporciona unas conclusiones globales finales, del mismo modo que hicimos en clase al explicar este cuaderno de PLN5 con los textos de ejemplo. La discusión (interpretación) de los resultados debes desarrollarla y argumentarla debidamente en una celda de markdown a continuación del código de esta actividad.

# %% [markdown]
# ## 💬 Preguntas de reflexión

# %% [markdown]
# Responde de forma debidamente argumentada a las siguientes cuestiones:
#
# 1. ¿Por qué puede haber una puntuación baja de BLEU aunque el significado sea correcto?
# 2. ¿Qué limitaciones tiene la métrica "Exact Match"?
# 3. ¿Qué ventaja tiene usar varias métricas en lugar de una sola?
# 4. ¿Qué diferencias observas entre usar precisión/recall y usar BLEU?
# 5. ¿Te parece justo evaluar traducciones automáticas solo por coincidencias de palabras?

# %% [markdown]
# ## 📋 Rúbrica de evaluación

# %% [markdown]
# ⚖️ **Peso de esta actividad en la nota final:** cuatro actividades prácticas **15 % cada una** · preguntas de reflexión **40 %**
#
# 🧭 **Cómo se evalúa:** se valora **el procedimiento, no solo el resultado**. Resuelve la actividad con el método trabajado en el cuaderno principal de la unidad. Organizar el código a tu manera, usar otros nombres de variables o resolverlo de forma más breve **no penaliza**, siempre que se reconozca ese método. Lo que sí penaliza es sustituirlo por librerías o herramientas que no hemos trabajado y que no explicas.

# %% [markdown]
# | Criterio                                                       | Excelente (9-10)                        | Notable (7-8)                               | Aprobado (5-6)                               | Insuficiente (0-4)                     |
# |----------------------------------------------------------------|---------------------------------------|----------------------------------------|------------------------------------------|----------------------------------------|
# | Aplicación de métricas léxicas                                 | Calcula correctamente todas las métricas y las interpreta con claridad | Calcula la mayoría con corrección       | Algunas métricas con errores o confusiones | No aplica correctamente las métricas    |
# | Comprensión de BLEU y Exact Match                              | Explica claramente ambas métricas     | Explica una de ellas correctamente     | Confunde conceptos                       | No demuestra comprensión                 |
# | Interpretación de resultados                                    | Interpreta los valores con ejemplos   | Da una interpretación general          | Interpretación poco precisa               | No interpreta o lo hace incorrectamente |
# | Participación en actividades guiadas                           | Realiza todas con autonomía y reflexión | Realiza la mayoría correctamente       | Hace solo parte o necesita ayuda          | No participa activamente                 |
# | Reflexión crítica sobre las métricas                           | Argumenta con claridad y ejemplos     | Responde razonablemente                | Respuestas poco desarrolladas             | No responde o no reflexiona              |
