# %% [markdown]
# # Un breve resumen de Python

# %% [markdown]
# ## Los notebooks de Python

# %%
1

# %%
1+1

# %%
# Esto es un comentario
# Python ignorará esta línea, la de arriba y la de abajo
# Estas líneas solo están para la persona que lee el código
print(3 - 2)
5+2

# %% [markdown]
# ## Operadores básicos en Python

# %% [markdown]
# - `*` sirve para realizar multiplicaciones,
# - `/` para divisiones,
# - `//` ejecuta divisiones enteras (sin decimales),
# - `%` obtiene el módulo (el resto de una división), y
# - `**` se utilizan para la potencia.

# %%
2*3

# %%
4/3

# %%
4//3

# %%
2**3

# %%
16%12

# %% [markdown]
# Atajos de teclado:
#
# - `Alt + Enter`: ejecuta la celda actual, crea una nueva celda debajo y se desplaza a ella.
# - `Shift + Enter`: ejecuta la celda actual y pasa a la siguiente.
# - `Ctrl + Enter`: ejecuta la celda sin cambiar de posición.

# %% [markdown]
# ## Textos como cadenas de caracteres

# %%
"¡Hola mundo!"

# %%
'Hola mundo'

# %%
"En el artículo de la revista se afirmaba que "el premio se lo llevó la influencer mejor vestida""

# %%
"En el artículo de la revista se afirmaba que \"el premio se lo llevó la influencer mejor vestida\""

# %%
"un renglón
otro renglón"

# %%
"Hola:\nesto está en una nueva línea."

# %%
print("Hola:\nesto está en una nueva línea.")

# %%
print("manzana\tpera\nnaranja\tplátano")

# %% [markdown]
# Caracteres específicos de [Unicode](https://v4py.github.io/unicode.html) --> `\N{...}`.

# %%
"\N{see-no-evil monkey}"

# %%
"""un renglón
otro renglón
un renglón más
el último renglón"""

# %%
print("""un renglón
otro renglón
un renglón más
el último renglón""")

# %% [markdown]
# ## Objetos y variables

# %%
print

# %%
cadena = "manzana\tpera\nnaranja\tplátano"
cadena

# %%
print(cadena)

# %%
otro_nombre = cadena
print(otro_nombre)

# %%
cadena is otro_nombre

# %%
cadena is print

# %%
cadena2 = "manzana\tpera\nnaranja\tplátano"
cadena is cadena2

# %%
cadena == cadena2

# %% [markdown]
# ## Atributos: objetos en objetos (en objetos ...)

# %%
c = 1 + 2j
c

# %%
c.

# %%
c.real
# "real" es una propiedad (atributo) del objeto "c". Es la propiedad "número real".

# %%
c.imag
# "imag" es una propiedad (atributo) del objeto "c". Es la propiedad "número imaginario".

# %% [markdown]
# ### Métodos

# %%
print

# %%
c = 1 + 2j
c.conjugate

# %% [markdown]
# [Conjugados:](https://es.wikipedia.org/wiki/N%C3%BAmero_complejo#Conjugado_de_un_n%C3%BAmero_complejo)

# %%
c.conjugate()

# %%
cadena.

# %%
"gato".islower()

# %%
"PERRO".isupper()

# %%
"María".istitle()

# %%
"5543".isnumeric()

# %%
# ?cadena.islower

# %%
"Me gusta comer tanto carne como pescado.".replace("carne","verdura")

# %%
# ?cadena.replace

# %%
animal = "ornitorrinco"
animal.upper()

# %%
animal

# %%
nombre1 = "listado"
nombre2 = nombre1

# %%
nombre1

# %%
nombre2

# %%
nombre2 = nombre2.upper()
nombre2

# %%
nombre1

# %% [markdown]
# ## Colecciones

# %%
elemento1 = "Barriga"
elemento2 = "llena"
elemento3 = ","
elemento4 = "corazón"
elemento5 = "contento"

# %%
elementos = ["Barriga", "llena", ",", "corazón", "contento"]

# %% [markdown]
# ### Elementos de una colección

# %%
[55, "cuarenta y dos", print]

# %%
[]

# %%
(55, "cuarenta y dos", print)

# %%
()
# Out:
# ()

# %%
{"blue": "azul", "red": "rojo"}

# %%
{"impar": 1, "par": 2, "impar": 3, "par": 4}

# %%
{"par": [2,4], "impar": [1,3]}

# %%
ejemplo = {"par": [2,4], "impar": [1,3]}
ejemplo["par"]

# %%
{}
# Out:
# {}

# %%
{1, 2, 3, 1, 2, 3}

# %%
{"los", "trapecistas", "son", "los", "mejores", "artistas"}

# %%
set()

# %% [markdown]
# ### Algunas funciones comunes

# %%
len(["pera", "manzana", "naranja"])

# %%
len("Reino de España")

# %%
len({"naranja": "orange", "manzana": "apple"})

# %%
"azul" in ["rojo", "amarillo", "verde", "azul"]

# %%
"dos" in [1, 2, 3]

# %%
"manzana" in {"manzana": "apple", "naranja": "orange"}

# %%
"apple" in {"manzana": "apple", "naranja": "orange"}

# %%
slice_palabra = "comadreja"

# %%
slice_palabra[1:4]

# %%
slice_palabra[1:]

# %%
slice_palabra[:]

# %%
slice_palabra[4]

# %%
slice_palabra[:-3]

# %%
slice_palabra[-3:]

# %%
dic = {"naranja": "orange", "manzana": "apple"}
dic[0]

# %%
conjunto = {"manzana", "pera", "plátano"}
conjunto[0]

# %%
lista = ["gato", "perro", "pato"]
del lista[0]
lista

# %%
tupla = ("amarillo", "verde", "morado")
del tupla[0]
tupla

# %%
conjunto = {"one", "two", "three"}
del conjunto[0]
conjunto

# %%
dic = {"casa": "house", "ventana": "window"}
del dic["casa"]
dic

# %%
dic = {"casa": "house", "ventana": "window"}
del dic["house"]
dic

# %%
mi_conjunto = {5, 2, 8}

nueva_lista = list(mi_conjunto)

print(nueva_lista[0])
print(nueva_lista[1])

# %% [markdown]
# ## Flujos de control

# %% [markdown]
# ### Condicionales if-else
#
# ```
# if <condición>:
#   <código que se va a ejecutar si la condición es verdadera>
# else:
#   <código que se va a ejecutar si la condición no se cumple>
# ```

# %%
n = 5 # Prueba a cambiar el valor asignado a n
if (n%2 == 0):
  print("par")
else:
  print("impar")

# %%
n = 8 # Prueba a cambiar el valor asignado a n
if (n%2 == 0):
  print("par")
else:
  print("impar")

# %%
n = 6
if (n%2 == 0):
  print("Entro por el if")
  print("par")
else:
  print("Entro por el else")
  print("impar")

# %%
n = 9 # Prueba a cambiar el valor asignado a n
if (n%2 == 0):
  print("Entro por el if")
  print("par")
else:
  print("Entro por el else")
  print("impar")

# %%
n = 5 # Prueba a cambiar el valor asignado a n
if (n%2 == 0):
  print("Es un número par")

print("Continúo con la ejecución")

# %%
n = 2 # Prueba a cambiar el valor asignado a n
if (n%2 == 0):
  print("Es un número par")

print("Continúo con la ejecución")

# %% [markdown]
# ### Bucles
#
# ```
# for <elemento> in <coleccion>:
#   ...
# ```

# %%
frase = "Barriga llena, corazón contento"
palabrasFrase = frase.split(' ')
sumaLongitudes = 0
for palabra in palabrasFrase:
  print("Valor suma longitud: ", sumaLongitudes)
  sumaLongitudes = sumaLongitudes + len(palabra)
sumaLongitudes / len(palabrasFrase)

# %% [markdown]
# ## Definición de funciones

# %% [markdown]
# ```
# def <nombre-funcion> (<entrada1>, <entrada2>, ..., <entradaN>):
#   # Código que se ejecuta con los parámetros de entrada
#   ...
#   return <valor-que-devuelve>
# ```

# %%
def frecuencia_texto(texto):
  frecuencias = {}
  for palabra in texto.split(' '):
    if palabra not in frecuencias:
      frecuencias[palabra] = 1
    else:
      frecuencias[palabra] = frecuencias[palabra] + 1
    print(frecuencias)

  return frecuencias

# %%
frecuencia_texto("Barriga llena, corazón contento")
# Out:
# {'Barriga': 1}
# {'Barriga': 1, 'llena,': 1}
# {'Barriga': 1, 'llena,': 1, 'corazón': 1}
# {'Barriga': 1, 'llena,': 1, 'corazón': 1, 'contento': 1}
# {'Barriga': 1, 'llena,': 1, 'corazón': 1, 'contento': 1}

# %% [markdown]
# **Ejercicio:** Crea una nueva función con el código que implementaste anteriormente para contar la frecuencia de cada palabra eliminando primero signos de puntuación y pasando el texto a minúsculas.

# %% [markdown]
# ## Importamos librerías adicionales

# %%
import nltk

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

frase = "Barriga llena, corazón contento."
tokens = tokenizer.tokenize(frase)

print(tokens)
